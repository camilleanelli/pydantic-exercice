# %% [markdown]
# ### Contexte
# Vous travaillez pour une entreprise de commerce électronique qui a collecté des données de ventes sur une année. Avant d'effectuer une analyse approfondie, l'entreprise souhaite s'assurer de la qualité et de la cohérence des données. Votre tâche est de créer un système de validation robuste en utilisant Pydantic v2.
#
# ### Objectifs
# 1. Créer des modèles Pydantic pour valider strictement les données de ventes.
# 2. Implémenter un système de validation qui identifie et catégorise les anomalies dans les données.
# 3. Générer un rapport détaillé sur la qualité des données.
#
# ### Données
# Vous disposez d'un fichier CSV nommé "ventes_detaillees.csv", disponible en téléchargement sur [ce lien](http://sc-e.fr/wcs/ventes_detaillees.csv), contenant les colonnes suivantes :
# id_vente, date, heure, id_produit, nom_produit, prix_produit, categorie_produit, quantite, pays, ville, methode_paiement, statut_commande, satisfaction_client
#
# ### Tâches
#
# 1. **Création des modèles Pydantic**
#    - Créez un modèle `Produit` avec les contraintes suivantes :
#      - `id`: doit commencer par 'P' suivi de 3 chiffres
#      - `nom`: chaîne non vide
#      - `prix`: nombre positif avec 2 décimales maximum
#      - `categorie`: doit être l'une des catégories prédéfinies (Électronique, Vêtements, Alimentation, Maison, Loisirs, Beauté, Électroménager, Livres, Sport, Papeterie, Accessoires)
#
#    - Créez un modèle `Vente` avec les contraintes suivantes :
#      - `id`: doit commencer par 'V' suivi de 6 chiffres
#      - `date` et `heure`: format valide
#      - `produit`: utilise le modèle `Produit`
#      - `quantite`: entier positif
#      - `pays`: doit être l'un des pays européens prédéfinis (France, Allemagne, Espagne, Italie, Royaume-Uni, Belgique, Pays-Bas, Suisse, Portugal, Autriche)
#      - `ville`: chaîne non vide
#      - `methode_paiement`: doit être l'une des méthodes prédéfinies (Carte de crédit, PayPal, Virement bancaire, Apple Pay, Google Pay)
#      - `statut_commande`: doit être l'un des statuts prédéfinis (En cours de traitement, Expédiée, Livrée, Annulée)
#      - `satisfaction_client`: entier entre 1 et 5
#
# 2. **Système de validation**
#    - Implémentez une fonction qui lit le CSV et valide chaque ligne.
#    - Catégorisez les erreurs (par exemple : erreur de format, valeur hors limites, valeur manquante).
#    - Comptabilisez les occurrences de chaque type d'erreur.
#
# 3. **Rapport de qualité des données**
#    - Générez un rapport indiquant :
#      - Le nombre total d'enregistrements traités
#      - Le nombre d'enregistrements valides
#      - Le nombre et le pourcentage d'enregistrements invalides
#      - Un résumé des types d'erreurs rencontrées et leur fréquence
#      - Des exemples d'enregistrements invalides pour chaque type d'erreur
#
# ### Code de départ

# %%
from pydantic import BaseModel, Field, field_validator, ValidationError
from typing import List
from datetime import date, time
import pandas as pd

def valider_donnees_ventes(chemin_fichier: str) -> tuple:
    # Implémentez la lecture du CSV et la validation ici
    pass

def generer_rapport_qualite(resultats_validation: tuple):
    # Implémentez la génération du rapport ici
    pass

if __name__ == "__main__":
    resultats = valider_donnees_ventes("ventes_detaillees")
    generer_rapport_qualite(resultats)

# %% [markdown]
# ### Conseils
# - Utilisez les fonctionnalités de Pydantic comme `Field`, `field_validator` pour définir des contraintes complexes.
# - Pensez à gérer les cas particuliers comme les valeurs manquantes ou mal formatées.
# - Pour le rapport, essayez de fournir des informations utiles qui aideraient à comprendre la nature et l'étendue des problèmes de qualité des données.
# - N'oubliez pas de traiter les dates et heures correctement lors de la lecture du CSV.
#
# Bonne chance !

# %%
from collections import defaultdict


errors = defaultdict(list)
errors["toot"] = ["hello", "world"]

errors["toot"].append("totot")
print(errors)
# Out:
# defaultdict(<class 'list'>, {'toot': ['hello', 'world', 'totot']})

# %%
"""
id: doit commencer par 'P' suivi de 3 chiffres
nom: chaîne non vide
prix: nombre positif avec 2 décimales maximum
categorie: doit être l'une des catégories prédéfinies (Électronique, Vêtements, Alimentation, Maison, Loisirs, Beauté, Électroménager, Livres, Sport, Papeterie, Accessoires)
"""

class Produit(BaseModel):
  id: str = Field(..., pattern=r"^P\d{3}")
  name: str = Field(..., min_length=1)
  price: float = Field(..., gt=0)
  category: str

  @field_validator('category')
  @classmethod
  def valid_category(cls, value: str) -> str:
    cat = ["Électronique", "Vêtements", 'Alimentation', 'Maison', "Loisirs", "Beauté", "Électroménager", "Livres", "Sport", 'Papeterie', 'Accessoires']
    if value not in cat:
      raise ValueError(f"The category should be: {''.join(cat)}")
    return value

  @field_validator('price')
  @classmethod
  def valid_price(cls, price: float) -> float:
    return round(price, 2)

# %%
'''
id: doit commencer par 'V' suivi de 6 chiffres
date et heure: format valide
produit: utilise le modèle Produit
quantite: entier positif
pays: doit être l'un des pays européens prédéfinis (France, Allemagne, Espagne, Italie, Royaume-Uni, Belgique, Pays-Bas, Suisse, Portugal, Autriche)
ville: chaîne non vide
methode_paiement: doit être l'une des méthodes prédéfinies (Carte de crédit, PayPal, Virement bancaire, Apple Pay, Google Pay)
statut_commande: doit être l'un des statuts prédéfinis (En cours de traitement, Expédiée, Livrée, Annulée)
satisfaction_client: entier entre 1 et 5
'''

# Vente

class Vente(BaseModel):
  id: str = Field(..., pattern=r'^V\d{6}')
  date: date
  time: time
  produit: Produit
  quantity: int = Field(..., gt=0)
  country: str
  city: str = Field(..., min_length=1)
  payment: str
  order_status: str
  satisfaction: int = Field(..., ge=1, le=5)

  @field_validator("country")
  @classmethod
  def valid_country(cls, value: str) -> str:
    valid_countries = ['France', 'Allemagne', 'Espagne', 'Italie', 'Royaume-Uni', 'Belgique', 'Pays-Bas', 'Suisse', 'Portugal','Autriche']
    if value not in valid_countries:
      raise ValueError(f"Country must be one of the list: {','.join(valid_countries)}")
    return value

  @field_validator("payment")
  @classmethod
  def valid_payment_method(cls, value: str) -> str:
    valid_methods = ['Carte de crédit', 'PayPal', 'Virement bancaire', 'Apple Pay', 'Google Pay']
    if value not in valid_methods:
      raise ValueError(f"Payment must be: {','.join(valid_methods)}")
    return value

  @field_validator('order_status')
  @classmethod
  def valid_status(cls, value: str) -> str:
    valid_status = ['En cours de traitement', 'Expédiée', 'Livrée', 'Annulée']
    if value not in valid_status:
      raise ValueError(f"The status must be: {','.join(valid_status)}")
    return value

# %%
'''
Implémentez une fonction qui lit le CSV et valide chaque ligne.
Catégorisez les erreurs (par exemple : erreur de format, valeur hors limites, valeur manquante).
Comptabilisez les occurrences de chaque type d'erreur.
'''

df = pd.read_csv("http://sc-e.fr/wcs/ventes_detaillees.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_vente             10000 non-null  object
#  1   date                 10000 non-null  object
#  2   heure                10000 non-null  object
#  3   id_produit           10000 non-null  object
#  4   nom_produit          10000 non-null  object
#  5   prix_produit         10000 non-null  float64
#  6   categorie_produit    10000 non-null  object
#  7   quantite             10000 non-null  int64
#  8   pays                 10000 non-null  object
#  9   ville                10000 non-null  object
#  10  methode_paiement     10000 non-null  object
#  11  statut_commande      10000 non-null  object
#  12  satisfaction_client  10000 non-null  int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 1015.8+ KB

# %%
def read_and_validate(file):
  df = pd.read_csv(file)
  all_errors = defaultdict(list)
  total_items = 0
  invalid_items = []

  for index, vente in df.iterrows():
      total_items +=1
      try:
          produit = Produit(id = vente['id_produit'],
                            name=vente['nom_produit'],
                            price = vente['prix_produit'],
                            category = vente['categorie_produit']
                            )
          value = Vente(
          id = vente['id_vente'],
          date = vente['date'],
          time = vente['heure'],
          produit = produit,
          quantity = vente['quantite'],
          country = vente['pays'],
          city = vente['ville'],
          payment = vente['methode_paiement'],
          order_status = vente['statut_commande'],
          satisfaction = vente['satisfaction_client']
          )

      except ValidationError as e:
         invalid_items.append(index)
         for error in e.errors():
            all_errors[error['type']].append([error['loc'][0], index])
  occurences_for_type_error = {}
  for key, value in all_errors.items():
    occurences_for_type_error[key] = len(value)

  return total_items, len(invalid_items), occurences_for_type_error, all_errors





read_and_validate("http://sc-e.fr/wcs/ventes_detaillees.csv")
# Out:
# (10000,
#  1000,
#  {'greater_than': 329,
#   'value_error': 339,
#   'string_pattern_mismatch': 160,
#   'less_than_equal': 172},
#  defaultdict(list,
#              {'greater_than': [['price', 1],
#                ['quantity', 20],
#                ['price', 27],
#                ['price', 35],
#                ['price', 37],
#                ['quantity', 111],
#                ['quantity', 156],
#                ['quantity', 158],
#                ['price', 167],
#                ['price', 173],
#                ['quantity', 201],
#                ['price', 232],
#                ['quantity', 256],
#                ['price', 274],
#                ['price', 359],
#                ['price', 369],
#                ['price', 382],
#                ['quantity', 408],
#                ['price', 436],
#                ['quantity', 484],
#                ['quantity', 490],
#                ['price', 571],
#                ['quantity', 572],
#                ['quantity', 600],
#                ['price', 656],
#                ['price', 669],
#                ['quantity', 689],
#                ['price', 715],
#                ['quantity', 730],
#                ['price', 761],
#                ['quantity', 774],
#                ['price', 819],
#                ['price', 897],
#                ['price', 914],
#                ['quantity', 917],
#                ['quantity', 951],
#                ['price', 967],
#                ['quantity', 1029],
#                ['quantity', 1043],
#                ['quantity', 1051],
#                ['quantity', 1137],
#                ['price', 1218],
#                ['price', 1219],
#                ['price', 1230],
#                ['quantity', 1271],
#                ['quantity', 1309],
#                ['price', 1367],
#                ['quantity', 1400],
#                ['price', 1446],
#                ['quantity', 1459],
#                ['quantity', 1463],
#                ['quantity', 1475],
#                ['quantity', 1484],
#                ['price', 1527],
#                ['quantity', 1549],
#                ['quantity', 1559],
#                ['quantity', 1568],
#                ['price', 1576],
#                ['price', 1580],
#                ['price', 1607],
#                ['quantity', 1616],
#                ['quantity', 1697],
#                ['quantity', 1726],
#                ['quantity', 1737],
#                ['quantity', 1789],
#                ['price', 1832],
#                ['quantity', 1834],
#                ['quantity', 1853],
#                ['price', 1872],
#                ['price', 1972],
#                ['quantity', 1979],
#                ['price', 2040],
#                ['quantity', 2074],
#                ['quantity', 2118],
#                ['price', 2182],
#                ['quantity', 2187],
#                ['price', 2201],
#                ['quantity', 2249],
#                ['price', 2395],
#                ['quantity', 2429],
#                ['quantity', 2435],
#                ['quantity', 2439],
#                ['price', 2605],
#                ['quantity', 2618],
#                ['price', 2675],
#                ['quantity', 2713],
#                ['price', 2730],
#                ['quantity', 2760],
#                ['price', 2778],
#                ['price', 2845],
#                ['quantity', 2853],
#                ['quantity', 2865],
#                ['price', 2885],
#                ['quantity', 2961],
#                ['quantity', 2964],
#                ['quantity', 3050],
#                ['quantity', 3057],
#                ['price', 3077],
#                ['price', 3213],
#                ['price', 3263],
#                ['quantity', 3279],
#                ['price', 3308],
#                ['quantity', 3322],
#                ['price', 3325],
#                ['price', 3337],
#                ['price', 3405],
#                ['quantity', 3443],
#                ['quantity', 3444],
#                ['quantity', 3453],
#                ['quantity', 3506],
#                ['quantity', 3553],
#                ['quantity', 3571],
#                ['quantity', 3591],
#                ['quantity', 3600],
#                ['quantity', 3614],
#                ['price', 3622],
#                ['quantity', 3653],
#                ['quantity', 3680],
#                ['quantity', 3804],
#                ['quantity', 3811],
#                ['price', 3931],
#                ['price', 3947],
#                ['price', 3961],
#                ['price', 3991],
#                ['price', 3997],
#                ['price', 4001],
#                ['quantity', 4015],
#                ['quantity', 4021],
#                ['price', 4071],
#                ['price', 4077],
#                ['quantity', 4094],
#                ['quantity', 4150],
#                ['quantity', 4307],
#                ['price', 4320],
#                ['quantity', 4329],
#                ['quantity', 4352],
#                ['quantity', 4368],
#                ['quantity', 4459],
#                ['price', 4460],
#                ['quantity', 4542],
#                ['quantity', 4632],
#                ['price', 4647],
#                ['price', 4698],
#                ['quantity', 4734],
#                ['price', 4769],
#                ['quantity', 4808],
#                ['price', 4816],
#                ['price', 4848],
#                ['price', 4857],
#                ['quantity', 4867],
#                ['price', 4878],
#                ['quantity', 4925],
#                ['price', 4942],
#                ['price', 4970],
#                ['price', 4982],
#                ['price', 5028],
#                ['price', 5033],
#                ['price', 5055],
#                ['price', 5118],
#                ['price', 5185],
#                ['price', 5214],
#                ['quantity', 5246],
#                ['quantity', 5247],
#                ['price', 5309],
#                ['quantity', 5329],
#                ['price', 5342],
#                ['price', 5346],
#                ['price', 5376],
#                ['price', 5377],
#                ['price', 5378],
#                ['price', 5385],
#                ['price', 5390],
#                ['price', 5427],
#                ['price', 5431],
#                ['quantity', 5522],
#                ['quantity', 5546],
#                ['price', 5558],
#                ['quantity', 5562],
#                ['quantity', 5591],
#                ['price', 5630],
#                ['price', 5648],
#                ['price', 5655],
#                ['price', 5668],
#                ['quantity', 5690],
#                ['quantity', 5704],
#                ['price', 5708],
#                ['quantity', 5765],
#                ['quantity', 5809],
#                ['price', 5841],
#                ['quantity', 5864],
#                ['price', 5865],
#                ['price', 5884],
#                ['price', 5887],
#                ['quantity', 5909],
#                ['price', 5911],
#                ['quantity', 5923],
#                ['quantity', 5931],
#                ['price', 5934],
#                ['quantity', 5954],
#                ['price', 5984],
#                ['price', 6012],
#                ['quantity', 6027],
#                ['quantity', 6030],
#                ['price', 6052],
#                ['quantity', 6054],
#                ['price', 6055],
#                ['price', 6108],
#                ['price', 6114],
#                ['price', 6153],
#                ['quantity', 6237],
#                ['price', 6282],
#                ['quantity', 6329],
#                ['price', 6362],
#                ['quantity', 6389],
#                ['price', 6462],
#                ['price', 6463],
#                ['price', 6507],
#                ['price', 6534],
#                ['price', 6538],
#                ['price', 6592],
#                ['quantity', 6648],
#                ['price', 6650],
#                ['quantity', 6683],
#                ['price', 6746],
#                ['price', 6837],
#                ['quantity', 6885],
#                ['quantity', 6912],
#                ['price', 6921],
#                ['price', 6973],
#                ['price', 7005],
#                ['price', 7015],
#                ['price', 7025],
#                ['price', 7046],
#                ['price', 7074],
#                ['price', 7090],
#                ['quantity', 7103],
#                ['price', 7106],
#                ['price', 7115],
#                ['price', 7118],
#                ['quantity', 7221],
#                ['quantity', 7296],
#                ['quantity', 7365],
#                ['quantity', 7412],
#                ['price', 7561],
#                ['price', 7624],
#                ['price', 7637],
#                ['price', 7644],
#                ['quantity', 7690],
#                ['price', 7693],
#                ['price', 7694],
#                ['price', 7709],
#                ['quantity', 7780],
#                ['price', 7823],
#                ['quantity', 7881],
#                ['price', 7895],
#                ['quantity', 7910],
#                ['price', 7927],
#                ['quantity', 7937],
#                ['quantity', 8018],
#                ['price', 8054],
#                ['quantity', 8110],
#                ['quantity', 8116],
#                ['quantity', 8175],
#                ['quantity', 8248],
#                ['price', 8254],
#                ['price', 8255],
#                ['price', 8257],
#                ['price', 8298],
#                ['quantity', 8326],
#                ['price', 8333],
#                ['quantity', 8381],
#                ['quantity', 8401],
#                ['quantity', 8502],
#                ['price', 8505],
#                ['price', 8569],
#                ['quantity', 8570],
#                ['price', 8606],
#                ['price', 8670],
#                ['quantity', 8675],
#                ['quantity', 8708],
#                ['price', 8751],
#                ['price', 8789],
#                ['quantity', 8868],
#                ['quantity', 8870],
#                ['quantity', 8894],
#                ['price', 8961],
#                ['quantity', 9004],
#                ['quantity', 9010],
#                ['price', 9021],
#                ['quantity', 9026],
#                ['quantity', 9031],
#                ['quantity', 9041],
#                ['quantity', 9074],
#                ['quantity', 9120],
#                ['quantity', 9132],
#                ['price', 9143],
#                ['price', 9159],
#                ['quantity', 9179],
#                ['price', 9257],
#                ['quantity', 9259],
#                ['price', 9261],
#                ['price', 9267],
#                ['quantity', 9284],
#                ['quantity', 9297],
#                ['price', 9337],
#                ['price', 9354],
#                ['quantity', 9384],
#                ['quantity', 9400],
#                ['price', 9416],
#                ['price', 9428],
#                ['quantity', 9448],
#                ['quantity', 9451],
#                ['price', 9488],
#                ['quantity', 9543],
#                ['quantity', 9575],
#                ['price', 9618],
#                ['price', 9669],
#                ['quantity', 9699],
#                ['price', 9708],
#                ['quantity', 9786],
#                ['quantity', 9804],
#                ['quantity', 9831],
#                ['price', 9871],
#                ['quantity', 9882],
#                ['price', 9890],
#                ['price', 9912],
#                ['price', 9952],
#                ['price', 9977],
#                ['quantity', 9998]],
#               'value_error': [['category', 13],
#                ['category', 38],
#                ['country', 92],
#                ['category', 114],
#                ['country', 162],
#                ['category', 231],
#                ['country', 287],
#                ['category', 318],
#                ['category', 322],
#                ['country', 493],
#                ['category', 587],
#                ['country', 614],
#                ['country', 670],
#                ['country', 739],
#                ['country', 755],
#                ['category', 757],
#                ['country', 809],
#                ['category', 844],
#                ['category', 881],
#                ['country', 932],
#                ['country', 934],
#                ['country', 938],
#                ['category', 1023],
#                ['category', 1082],
#                ['country', 1099],
#                ['category', 1136],
#                ['country', 1155],
#                ['country', 1183],
#                ['country', 1194],
#                ['country', 1257],
#                ['country', 1282],
#                ['country', 1283],
#                ['country', 1296],
#                ['category', 1305],
#                ['country', 1307],
#                ['country', 1310],
#                ['category', 1370],
#                ['country', 1390],
#                ['country', 1394],
#                ['category', 1421],
#                ['country', 1423],
#                ['country', 1428],
#                ['category', 1445],
#                ['category', 1451],
#                ['category', 1488],
#                ['category', 1495],
#                ['category', 1594],
#                ['country', 1637],
#                ['category', 1724],
#                ['country', 1734],
#                ['country', 1768],
#                ['country', 1774],
#                ['category', 1788],
#                ['category', 1794],
#                ['category', 1863],
#                ['country', 1919],
#                ['category', 1942],
#                ['category', 1957],
#                ['category', 2010],
#                ['category', 2095],
#                ['category', 2099],
#                ['category', 2111],
#                ['category', 2127],
#                ['country', 2133],
#                ['category', 2209],
#                ['country', 2224],
#                ['category', 2245],
#                ['country', 2264],
#                ['category', 2336],
#                ['category', 2345],
#                ['country', 2431],
#                ['country', 2507],
#                ['country', 2531],
#                ['country', 2545],
#                ['category', 2556],
#                ['category', 2560],
#                ['country', 2647],
#                ['category', 2671],
#                ['category', 2677],
#                ['category', 2712],
#                ['country', 2828],
#                ['country', 2842],
#                ['country', 2879],
#                ['category', 2886],
#                ['category', 2896],
#                ['country', 2903],
#                ['category', 2933],
#                ['category', 2944],
#                ['country', 2960],
#                ['country', 3021],
#                ['country', 3040],
#                ['category', 3059],
#                ['country', 3061],
#                ['country', 3123],
#                ['country', 3131],
#                ['category', 3202],
#                ['category', 3214],
#                ['country', 3252],
#                ['category', 3264],
#                ['category', 3283],
#                ['category', 3296],
#                ['category', 3305],
#                ['country', 3328],
#                ['category', 3362],
#                ['country', 3384],
#                ['category', 3415],
#                ['category', 3421],
#                ['country', 3423],
#                ['country', 3424],
#                ['country', 3448],
#                ['country', 3498],
#                ['category', 3527],
#                ['country', 3556],
#                ['country', 3568],
#                ['country', 3576],
#                ['country', 3585],
#                ['country', 3650],
#                ['country', 3707],
#                ['category', 3746],
#                ['country', 3795],
#                ['category', 3801],
#                ['country', 3807],
#                ['country', 3817],
#                ['category', 3865],
#                ['country', 3938],
#                ['country', 3964],
#                ['category', 3988],
#                ['category', 4028],
#                ['category', 4033],
#                ['category', 4047],
#                ['category', 4140],
#                ['category', 4155],
#                ['country', 4169],
#                ['country', 4194],
#                ['country', 4202],
#                ['country', 4250],
#                ['category', 4254],
#                ['category', 4257],
#                ['category', 4280],
#                ['category', 4282],
#                ['category', 4293],
#                ['country', 4296],
#                ['category', 4314],
#                ['category', 4405],
#                ['category', 4413],
#                ['country', 4443],
#                ['category', 4522],
#                ['category', 4545],
#                ['country', 4616],
#                ['category', 4635],
#                ['country', 4661],
#                ['country', 4662],
#                ['country', 4674],
#                ['category', 4705],
#                ['country', 4706],
#                ['category', 4736],
#                ['category', 4797],
#                ['country', 4849],
#                ['country', 4880],
#                ['category', 4915],
#                ['category', 4921],
#                ['country', 4932],
#                ['country', 4933],
#                ['category', 4973],
#                ['country', 4975],
#                ['category', 5076],
#                ['category', 5091],
#                ['category', 5105],
#                ['category', 5111],
#                ['country', 5150],
#                ['category', 5153],
#                ['country', 5194],
#                ['category', 5285],
#                ['category', 5292],
#                ['country', 5304],
#                ['country', 5373],
#                ['category', 5408],
#                ['category', 5412],
#                ['category', 5471],
#                ['category', 5523],
#                ['category', 5556],
#                ['country', 5570],
#                ['country', 5577],
#                ['category', 5604],
#                ['country', 5663],
#                ['country', 5678],
#                ['category', 5719],
#                ['country', 5747],
#                ['category', 5760],
#                ['category', 5766],
#                ['category', 5773],
#                ['country', 5775],
#                ['category', 5842],
#                ['category', 5868],
#                ['country', 5902],
#                ['country', 5914],
#                ['category', 5926],
#                ['category', 6000],
#                ['category', 6004],
#                ['category', 6021],
#                ['country', 6056],
#                ['category', 6062],
#                ['country', 6063],
#                ['category', 6081],
#                ['category', 6111],
#                ['country', 6155],
#                ['country', 6194],
#                ['country', 6204],
#                ['country', 6247],
#                ['country', 6285],
#                ['category', 6293],
#                ['country', 6342],
#                ['category', 6375],
#                ['category', 6402],
#                ['category', 6487],
#                ['country', 6494],
#                ['country', 6499],
#                ['country', 6516],
#                ['country', 6531],
#                ['country', 6536],
#                ['category', 6546],
#                ['country', 6583],
#                ['country', 6589],
#                ['country', 6656],
#                ['category', 6663],
#                ['category', 6672],
#                ['category', 6688],
#                ['category', 6721],
#                ['country', 6763],
#                ['category', 6800],
#                ['country', 6890],
#                ['country', 6891],
#                ['country', 6952],
#                ['category', 6979],
#                ['category', 7007],
#                ['country', 7033],
#                ['category', 7047],
#                ['country', 7084],
#                ['category', 7113],
#                ['category', 7147],
#                ['category', 7148],
#                ['category', 7157],
#                ['country', 7171],
#                ['country', 7172],
#                ['country', 7215],
#                ['category', 7216],
#                ['country', 7270],
#                ['category', 7333],
#                ['country', 7355],
#                ['category', 7356],
#                ['category', 7361],
#                ['category', 7363],
#                ['country', 7410],
#                ['category', 7419],
#                ['category', 7422],
#                ['category', 7545],
#                ['country', 7546],
#                ['category', 7556],
#                ['country', 7641],
#                ['category', 7652],
#                ['country', 7664],
#                ['country', 7686],
#                ['country', 7696],
#                ['country', 7723],
#                ['category', 7776],
#                ['category', 7785],
#                ['category', 7796],
#                ['category', 7930],
#                ['country', 7959],
#                ['country', 8055],
#                ['category', 8080],
#                ['category', 8093],
#                ['category', 8178],
#                ['country', 8182],
#                ['country', 8201],
#                ['country', 8212],
#                ['category', 8219],
#                ['category', 8266],
#                ['category', 8276],
#                ['country', 8284],
#                ['country', 8346],
#                ['category', 8360],
#                ['country', 8369],
#                ['country', 8379],
#                ['country', 8388],
#                ['country', 8416],
#                ['category', 8448],
#                ['country', 8449],
#                ['category', 8500],
#                ['country', 8514],
#                ['country', 8537],
#                ['country', 8562],
#                ['category', 8584],
#                ['category', 8603],
#                ['category', 8618],
#                ['category', 8645],
#                ['category', 8651],
#                ['country', 8680],
#                ['category', 8688],
#                ['category', 8835],
#                ['country', 8889],
#                ['category', 8905],
#                ['country', 8950],
#                ['category', 8956],
#                ['country', 9007],
#                ['category', 9060],
#                ['country', 9069],
#                ['category', 9093],
#                ['country', 9115],
#                ['category', 9116],
#                ['category', 9117],
#                ['country', 9175],
#                ['country', 9183],
#                ['country', 9265],
#                ['category', 9279],
#                ['country', 9328],
#                ['country', 9347],
#                ['category', 9364],
#                ['category', 9365],
#                ['category', 9373],
#                ['category', 9381],
#                ['category', 9427],
#                ['country', 9466],
#                ['category', 9521],
#                ['category', 9542],
#                ['category', 9544],
#                ['country', 9558],
#                ['category', 9605],
#                ['category', 9629],
#                ['country', 9632],
#                ['category', 9634],
#                ['category', 9647],
#                ['country', 9673],
#                ['country', 9679],
#                ['category', 9706],
#                ['country', 9732],
#                ['country', 9766],
#                ['country', 9787],
#                ['category', 9897]],
#               'string_pattern_mismatch': [['id', 41],
#                ['id', 67],
#                ['id', 113],
#                ['id', 165],
#                ['id', 178],
#                ['id', 230],
#                ['id', 254],
#                ['id', 346],
#                ['id', 361],
#                ['id', 396],
#                ['id', 399],
#                ['id', 433],
#                ['id', 492],
#                ['id', 575],
#                ['id', 592],
#                ['id', 596],
#                ['id', 615],
#                ['id', 668],
#                ['id', 810],
#                ['id', 846],
#                ['id', 867],
#                ['id', 1134],
#                ['id', 1181],
#                ['id', 1201],
#                ['id', 1202],
#                ['id', 1227],
#                ['id', 1233],
#                ['id', 1243],
#                ['id', 1453],
#                ['id', 1465],
#                ['id', 1522],
#                ['id', 1620],
#                ['id', 1706],
#                ['id', 1707],
#                ['id', 1761],
#                ['id', 1819],
#                ['id', 1827],
#                ['id', 1835],
#                ['id', 1950],
#                ['id', 1989],
#                ['id', 2055],
#                ['id', 2160],
#                ['id', 2177],
#                ['id', 2277],
#                ['id', 2344],
#                ['id', 2441],
#                ['id', 2454],
#                ['id', 2606],
#                ['id', 2714],
#                ['id', 2808],
#                ['id', 2831],
#                ['id', 2979],
#                ['id', 3028],
#                ['id', 3145],
#                ['id', 3219],
#                ['id', 3261],
#                ['id', 3290],
#                ['id', 3351],
#                ['id', 3367],
#                ['id', 3369],
#                ['id', 3378],
#                ['id', 3683],
#                ['id', 3695],
#                ['id', 3705],
#                ['id', 3896],
#                ['id', 3915],
#                ['id', 3992],
#                ['id', 4148],
#                ['id', 4218],
#                ['id', 4256],
#                ['id', 4361],
#                ['id', 4432],
#                ['id', 4435],
#                ['id', 4593],
#                ['id', 4686],
#                ['id', 4902],
#                ['id', 4919],
#                ['id', 4929],
#                ['id', 4981],
#                ['id', 5130],
#                ['id', 5145],
#                ['id', 5188],
#                ['id', 5261],
#                ['id', 5265],
#                ['id', 5289],
#                ['id', 5317],
#                ['id', 5482],
#                ['id', 5496],
#                ['id', 5508],
#                ['id', 5551],
#                ['id', 5564],
#                ['id', 5619],
#                ['id', 5647],
#                ['id', 5703],
#                ['id', 5811],
#                ['id', 5830],
#                ['id', 5903],
#                ['id', 5905],
#                ['id', 5997],
#                ['id', 6008],
#                ['id', 6074],
#                ['id', 6168],
#                ['id', 6192],
#                ['id', 6199],
#                ['id', 6280],
#                ['id', 6469],
#                ['id', 6493],
#                ['id', 6591],
#                ['id', 6621],
#                ['id', 6715],
#                ['id', 6783],
#                ['id', 6791],
#                ['id', 6807],
#                ['id', 6930],
#                ['id', 6990],
#                ['id', 7065],
#                ['id', 7087],
#                ['id', 7121],
#                ['id', 7139],
#                ['id', 7156],
#                ['id', 7209],
#                ['id', 7244],
#                ['id', 7439],
#                ['id', 7447],
#                ['id', 7453],
#                ['id', 7714],
#                ['id', 7817],
#                ['id', 7924],
#                ['id', 7931],
#                ['id', 8040],
#                ['id', 8111],
#                ['id', 8234],
#                ['id', 8340],
#                ['id', 8415],
#                ['id', 8445],
#                ['id', 8558],
#                ['id', 8692],
#                ['id', 8855],
#                ['id', 8965],
#                ['id', 8967],
#                ['id', 8991],
#                ['id', 9061],
#                ['id', 9125],
#                ['id', 9198],
#                ['id', 9222],
#                ['id', 9227],
#                ['id', 9332],
#                ['id', 9344],
#                ['id', 9349],
#                ['id', 9370],
#                ['id', 9372],
#                ['id', 9409],
#                ['id', 9597],
#                ['id', 9631],
#                ['id', 9656],
#                ['id', 9676],
#                ['id', 9798],
#                ['id', 9829],
#                ['id', 9895],
#                ['id', 9986]],
#               'less_than_equal': [['satisfaction', 88],
#                ['satisfaction', 166],
#                ['satisfaction', 241],
#                ['satisfaction', 282],
#                ['satisfaction', 344],
#                ['satisfaction', 354],
#                ['satisfaction', 363],
#                ['satisfaction', 389],
#                ['satisfaction', 390],
#                ['satisfaction', 444],
#                ['satisfaction', 497],
#                ['satisfaction', 513],
#                ['satisfaction', 528],
#                ['satisfaction', 601],
#                ['satisfaction', 643],
#                ['satisfaction', 655],
#                ['satisfaction', 731],
#                ['satisfaction', 785],
#                ['satisfaction', 789],
#                ['satisfaction', 801],
#                ['satisfaction', 911],
#                ['satisfaction', 1000],
#                ['satisfaction', 1034],
#                ['satisfaction', 1222],
#                ['satisfaction', 1316],
#                ['satisfaction', 1478],
#                ['satisfaction', 1491],
#                ['satisfaction', 1536],
#                ['satisfaction', 1756],
#                ['satisfaction', 1792],
#                ['satisfaction', 1896],
#                ['satisfaction', 1975],
#                ['satisfaction', 2156],
#                ['satisfaction', 2238],
#                ['satisfaction', 2243],
#                ['satisfaction', 2248],
#                ['satisfaction', 2357],
#                ['satisfaction', 2379],
#                ['satisfaction', 2386],
#                ['satisfaction', 2405],
#                ['satisfaction', 2511],
#                ['satisfaction', 2583],
#                ['satisfaction', 2656],
#                ['satisfaction', 2699],
#                ['satisfaction', 2737],
#                ['satisfaction', 2773],
#                ['satisfaction', 2882],
#                ['satisfaction', 2891],
#                ['satisfaction', 2945],
#                ['satisfaction', 2969],
#                ['satisfaction', 3139],
#                ['satisfaction', 3179],
#                ['satisfaction', 3420],
#                ['satisfaction', 3459],
#                ['satisfaction', 3544],
#                ['satisfaction', 3550],
#                ['satisfaction', 3564],
#                ['satisfaction', 3618],
#                ['satisfaction', 3799],
#                ['satisfaction', 3914],
#                ['satisfaction', 4046],
#                ['satisfaction', 4089],
#                ['satisfaction', 4109],
#                ['satisfaction', 4244],
#                ['satisfaction', 4766],
#                ['satisfaction', 4777],
#                ['satisfaction', 4795],
#                ['satisfaction', 5038],
#                ['satisfaction', 5042],
#                ['satisfaction', 5059],
#                ['satisfaction', 5089],
#                ['satisfaction', 5099],
#                ['satisfaction', 5176],
#                ['satisfaction', 5192],
#                ['satisfaction', 5257],
#                ['satisfaction', 5352],
#                ['satisfaction', 5354],
#                ['satisfaction', 5394],
#                ['satisfaction', 5426],
#                ['satisfaction', 5516],
#                ['satisfaction', 5530],
#                ['satisfaction', 5545],
#                ['satisfaction', 5670],
#                ['satisfaction', 5674],
#                ['satisfaction', 5680],
#                ['satisfaction', 5733],
#                ['satisfaction', 5737],
#                ['satisfaction', 5808],
#                ['satisfaction', 5819],
#                ['satisfaction', 5989],
#                ['satisfaction', 6060],
#                ['satisfaction', 6099],
#                ['satisfaction', 6130],
#                ['satisfaction', 6211],
#                ['satisfaction', 6232],
#                ['satisfaction', 6234],
#                ['satisfaction', 6296],
#                ['satisfaction', 6334],
#                ['satisfaction', 6340],
#                ['satisfaction', 6455],
#                ['satisfaction', 6503],
#                ['satisfaction', 6528],
#                ['satisfaction', 6548],
#                ['satisfaction', 6565],
#                ['satisfaction', 6725],
#                ['satisfaction', 6738],
#                ['satisfaction', 6806],
#                ['satisfaction', 6836],
#                ['satisfaction', 6844],
#                ['satisfaction', 6972],
#                ['satisfaction', 6998],
#                ['satisfaction', 7002],
#                ['satisfaction', 7012],
#                ['satisfaction', 7031],
#                ['satisfaction', 7038],
#                ['satisfaction', 7154],
#                ['satisfaction', 7161],
#                ['satisfaction', 7205],
#                ['satisfaction', 7222],
#                ['satisfaction', 7258],
#                ['satisfaction', 7259],
#                ['satisfaction', 7264],
#                ['satisfaction', 7266],
#                ['satisfaction', 7299],
#                ['satisfaction', 7334],
#                ['satisfaction', 7490],
#                ['satisfaction', 7524],
#                ['satisfaction', 7586],
#                ['satisfaction', 7706],
#                ['satisfaction', 7803],
#                ['satisfaction', 7830],
#                ['satisfaction', 7873],
#                ['satisfaction', 7884],
#                ['satisfaction', 7962],
#                ['satisfaction', 7986],
#                ['satisfaction', 8001],
#                ['satisfaction', 8024],
#                ['satisfaction', 8091],
#                ['satisfaction', 8114],
#                ['satisfaction', 8158],
#                ['satisfaction', 8163],
#                ['satisfaction', 8192],
#                ['satisfaction', 8232],
#                ['satisfaction', 8363],
#                ['satisfaction', 8446],
#                ['satisfaction', 8462],
#                ['satisfaction', 8466],
#                ['satisfaction', 8540],
#                ['satisfaction', 8615],
#                ['satisfaction', 8641],
#                ['satisfaction', 8657],
#                ['satisfaction', 8717],
#                ['satisfaction', 8819],
#                ['satisfaction', 8825],
#                ['satisfaction', 8837],
#                ['satisfaction', 8844],
#                ['satisfaction', 8921],
#                ['satisfaction', 9005],
#                ['satisfaction', 9091],
#                ['satisfaction', 9096],
#                ['satisfaction', 9154],
#                ['satisfaction', 9206],
#                ['satisfaction', 9255],
#                ['satisfaction', 9287],
#                ['satisfaction', 9307],
#                ['satisfaction', 9399],
#                ['satisfaction', 9585],
#                ['satisfaction', 9641],
#                ['satisfaction', 9813],
#                ['satisfaction', 9884],
#                ['satisfaction', 9889],
#                ['satisfaction', 9989]]}))

# %%
'''
Le nombre total d'enregistrements traités
Le nombre d'enregistrements valides
Le nombre et le pourcentage d'enregistrements invalides
Un résumé des types d'erreurs rencontrées et leur fréquence
Des exemples d'enregistrements invalides pour chaque type d'erreur
'''

def quality_report(infos: tuple):
  total_items, invalid_items, freq_by_error, errors_index = infos

  print(f"Total number of items: {total_items} ")
  print(f"Number of valid items: {total_items - invalid_items}")
  print(f"Number of invalid items: {invalid_items}")
  percent_invalid = (invalid_items / total_items) * 100
  print(f"Percent of invalid items: {percent_invalid}")
  print(f"Resume frequency of errors")
  for key, value in freq_by_error.items():
    print(f"For the error {key}, there are {value} invalid rows")
    print(f"example of errors")
    some_index = errors_index[key][0:4]
    for i in some_index:
      print(f"Column: {i[0]}")
      print(dict(df.iloc[i[1]]))


result = read_and_validate("http://sc-e.fr/wcs/ventes_detaillees.csv")
quality_report(result)
# Out:
# Number of items: 10000
# Number of valid items: 9000
# Number of invalid items: 1000
# Percent of invalid items: 10.0
# Resume frequency of errors
# For the error greater_than, there are 329 invalid rows
# example of errors
# Column: price
# {'id_vente': 'V000002', 'date': '2023-05-24', 'heure': '02:06:00', 'id_produit': 'P001', 'nom_produit': 'Smartphone', 'prix_produit': -499.99, 'categorie_produit': 'Électronique', 'quantite': 5, 'pays': 'France', 'ville': 'Ville_18_France', 'methode_paiement': 'Apple Pay', 'statut_commande': 'En cours de traitement', 'satisfaction_client': 5}
# Column: quantity
# {'id_vente': 'V000021', 'date': '2023-02-14', 'heure': '12:59:00', 'id_produit': 'P003', 'nom_produit': 'Livre de cuisine', 'prix_produit': 24.99, 'categorie_produit': 'Livres', 'quantite': 0, 'pays': 'Belgique', 'ville': 'Ville_5_Belgique', 'methode_paiement': 'Apple Pay', 'statut_commande': 'Livrée', 'satisfaction_client': 5}
# Column: price
# {'id_vente': 'V000028', 'date': '2023-09-04', 'heure': '00:37:00', 'id_produit': 'P018', 'nom_produit': 'Parfum', 'prix_produit': -69.99, 'categorie_produit': 'Beauté', 'quantite': 5, 'pays': 'France', 'ville': 'Ville_22_France', 'methode_paiement': 'PayPal', 'statut_commande': 'Expédiée', 'satisfaction_client': 2}
# Column: price
# {'id_vente': 'V000036', 'date': '2023-09-27', 'heure': '11:31:00', 'id_produit': 'P019', 'nom_produit': 'Couverture chauffante', 'prix_produit': -44.99, 'categorie_produit': 'Maison', 'quantite': 1, 'pays': 'Espagne', 'ville': 'Ville_33_Espagne', 'methode_paiement': 'Virement bancaire', 'statut_commande': 'Annulée', 'satisfaction_client': 1}
# For the error value_error, there are 339 invalid rows
# example of errors
# Column: category
# {'id_vente': 'V000014', 'date': '2023-01-18', 'heure': '04:58:00', 'id_produit': 'P011', 'nom_produit': 'Roman bestseller', 'prix_produit': 14.99, 'categorie_produit': 'Catégorie Invalide', 'quantite': 5, 'pays': 'France', 'ville': 'Ville_16_France', 'methode_paiement': 'Carte de crédit', 'statut_commande': 'Annulée', 'satisfaction_client': 3}
# Column: category
# {'id_vente': 'V000039', 'date': '2023-02-05', 'heure': '01:12:00', 'id_produit': 'P003', 'nom_produit': 'Livre de cuisine', 'prix_produit': 24.99, 'categorie_produit': 'Catégorie Invalide', 'quantite': 4, 'pays': 'France', 'ville': 'Ville_15_France', 'methode_paiement': 'Carte de crédit', 'statut_commande': 'Expédiée', 'satisfaction_client': 3}
# Column: country
# {'id_vente': 'V000093', 'date': '2023-07-21', 'heure': '05:07:00', 'id_produit': 'P006', 'nom_produit': 'Machine à café', 'prix_produit': 79.99, 'categorie_produit': 'Électroménager', 'quantite': 4, 'pays': 'Pays Inconnu', 'ville': 'Ville_30_Belgique', 'methode_paiement': 'PayPal', 'statut_commande': 'Expédiée', 'satisfaction_client': 1}
# Column: category
# {'id_vente': 'V000115', 'date': '2023-01-13', 'heure': '05:56:00', 'id_produit': 'P002', 'nom_produit': 'Ordinateur portable', 'prix_produit': 899.99, 'categorie_produit': 'Catégorie Invalide', 'quantite': 1, 'pays': 'France', 'ville': 'Ville_46_France', 'methode_paiement': 'Apple Pay', 'statut_commande': 'En cours de traitement', 'satisfaction_client': 3}
# For the error string_pattern_mismatch, there are 160 invalid rows
# example of errors
# Column: id
# {'id_vente': 'X000042', 'date': '2023-10-13', 'heure': '22:17:00', 'id_produit': 'P016', 'nom_produit': 'Tapis de yoga', 'prix_produit': 29.99, 'categorie_produit': 'Sport', 'quantite': 3, 'pays': 'Allemagne', 'ville': 'Ville_21_Allemagne', 'methode_paiement': 'PayPal', 'statut_commande': 'En cours de traitement', 'satisfaction_client': 1}
# Column: id
# {'id_vente': 'X000068', 'date': '2023-04-16', 'heure': '02:13:00', 'id_produit': 'P009', 'nom_produit': 'Aspirateur robot', 'prix_produit': 199.99, 'categorie_produit': 'Électroménager', 'quantite': 5, 'pays': 'Royaume-Uni', 'ville': 'Ville_16_Royaume-Uni', 'methode_paiement': 'Google Pay', 'statut_commande': 'Livrée', 'satisfaction_client': 2}
# Column: id
# {'id_vente': 'X000114', 'date': '2023-11-13', 'heure': '05:19:00', 'id_produit': 'P019', 'nom_produit': 'Couverture chauffante', 'prix_produit': 44.99, 'categorie_produit': 'Maison', 'quantite': 3, 'pays': 'France', 'ville': 'Ville_29_France', 'methode_paiement': 'Virement bancaire', 'statut_commande': 'Annulée', 'satisfaction_client': 5}
# Column: id
# {'id_vente': 'X000166', 'date': '2023-07-04', 'heure': '08:18:00', 'id_produit': 'P014', 'nom_produit': 'Appareil photo numérique', 'prix_produit': 349.99, 'categorie_produit': 'Électronique', 'quantite': 4, 'pays': 'France', 'ville': 'Ville_47_France', 'methode_paiement': 'Carte de crédit', 'statut_commande': 'En cours de traitement', 'satisfaction_client': 5}
# For the error less_than_equal, there are 172 invalid rows
# example of errors
# Column: satisfaction
# {'id_vente': 'V000089', 'date': '2023-10-23', 'heure': '21:11:00', 'id_produit': 'P015', 'nom_produit': 'Mixeur', 'prix_produit': 34.99, 'categorie_produit': 'Électroménager', 'quantite': 4, 'pays': 'Italie', 'ville': 'Ville_21_Italie', 'methode_paiement': 'Google Pay', 'statut_commande': 'Livrée', 'satisfaction_client': 10}
# Column: satisfaction
# {'id_vente': 'V000167', 'date': '2023-07-28', 'heure': '20:14:00', 'id_produit': 'P001', 'nom_produit': 'Smartphone', 'prix_produit': 499.99, 'categorie_produit': 'Électronique', 'quantite': 1, 'pays': 'France', 'ville': 'Ville_43_France', 'methode_paiement': 'PayPal', 'statut_commande': 'Expédiée', 'satisfaction_client': 10}
# Column: satisfaction
# {'id_vente': 'V000242', 'date': '2023-10-16', 'heure': '00:49:00', 'id_produit': 'P002', 'nom_produit': 'Ordinateur portable', 'prix_produit': 899.99, 'categorie_produit': 'Électronique', 'quantite': 4, 'pays': 'Italie', 'ville': 'Ville_25_Italie', 'methode_paiement': 'Google Pay', 'statut_commande': 'Expédiée', 'satisfaction_client': 10}
# Column: satisfaction
# {'id_vente': 'V000283', 'date': '2023-03-31', 'heure': '20:41:00', 'id_produit': 'P020', 'nom_produit': 'Jeu de société', 'prix_produit': 29.99, 'categorie_produit': 'Loisirs', 'quantite': 5, 'pays': 'France', 'ville': 'Ville_46_France', 'methode_paiement': 'Google Pay', 'statut_commande': 'Expédiée', 'satisfaction_client': 10}
